# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
arr = plt.imread(r'C:\Users\Dell\Downloads\car.jpg')

# %%
plt.imshow(arr)

# %%
arr.shape
# Out:
# (783, 1000, 3)

# %%
a = np.random.randint(0,255,(50,50,3))
plt.imshow(a)

# %%
while True:
    import numpy as np 
    import matplotlib.pyplot as plt 
    import time 
    a = np.random.randint(0,255,(50,50,3))
    plt.imshow(a)
    plt.show()
    time.sleep(0.3)
    display(clear = True)

# %%
a = np.random.randint(0,255,(4,4,3))
a
# Out:
# array([[[115, 157, 236],
#         [ 60, 143,  95],
#         [237,  56, 126],
#         [ 98,  20, 104]],
#
#        [[ 80, 243, 238],
#         [235, 186, 185],
#         [193, 131, 128],
#         [176,  14,  98]],
#
#        [[134, 203, 141],
#         [195, 225, 232],
#         [ 93,  30,   0],
#         [  4,  75, 163]],
#
#        [[ 95, 176,  27],
#         [ 16, 196,  50],
#         [142,  45,  25],
#         [  6, 174, 205]]], dtype=int32)

# %%
final_arr = np.split(a,2)
len(final_arr)
# Out:
# 2

# %%
plt.imshow(a)

# %%
plt.imshow(final_arr[0]) # half

# %%
plt.imshow(final_arr[1])

# %%
plt.imshow(a)

# %%
 arr_1 =np.split(a,2,axis=1)

# %%
len(arr_1)
# Out:
# 2

# %%
a
# Out:
# array([[[115, 157, 236],
#         [ 60, 143,  95],
#         [237,  56, 126],
#         [ 98,  20, 104]],
#
#        [[ 80, 243, 238],
#         [235, 186, 185],
#         [193, 131, 128],
#         [176,  14,  98]],
#
#        [[134, 203, 141],
#         [195, 225, 232],
#         [ 93,  30,   0],
#         [  4,  75, 163]],
#
#        [[ 95, 176,  27],
#         [ 16, 196,  50],
#         [142,  45,  25],
#         [  6, 174, 205]]], dtype=int32)

# %%
arr_1
# Out:
# [array([[[115, 157, 236],
#          [ 60, 143,  95]],
#
#         [[ 80, 243, 238],
#          [235, 186, 185]],
#
#         [[134, 203, 141],
#          [195, 225, 232]],
#
#         [[ 95, 176,  27],
#          [ 16, 196,  50]]], dtype=int32),
#  array([[[237,  56, 126],
#          [ 98,  20, 104]],
#
#         [[193, 131, 128],
#          [176,  14,  98]],
#
#         [[ 93,  30,   0],
#          [  4,  75, 163]],
#
#         [[142,  45,  25],
#          [  6, 174, 205]]], dtype=int32)]

# %%
a.shape
# Out:
# (4, 4, 3)

# %%
np.split(a,3, axis = 2)
# Out:
# [array([[[115],
#          [ 60],
#          [237],
#          [ 98]],
#
#         [[ 80],
#          [235],
#          [193],
#          [176]],
#
#         [[134],
#          [195],
#          [ 93],
#          [  4]],
#
#         [[ 95],
#          [ 16],
#          [142],
#          [  6]]], dtype=int32),
#  array([[[157],
#          [143],
#          [ 56],
#          [ 20]],
#
#         [[243],
#          [186],
#          [131],
#          [ 14]],
#
#         [[203],
#          [225],
#          [ 30],
#          [ 75]],
#
#         [[176],
#          [196],
#          [ 45],
#          [174]]], dtype=int32),
#  array([[[236],
#          [ 95],
#          [126],
#          [104]],
#
#         [[238],
#          [185],
#          [128],
#          [ 98]],
#
#         [[141],
#          [232],
#          [  0],
#          [163]],
#
#         [[ 27],
#          [ 50],
#          [ 25],
#          [205]]], dtype=int32)]

# %%
a
# Out:
# array([[[115, 157, 236],
#         [ 60, 143,  95],
#         [237,  56, 126],
#         [ 98,  20, 104]],
#
#        [[ 80, 243, 238],
#         [235, 186, 185],
#         [193, 131, 128],
#         [176,  14,  98]],
#
#        [[134, 203, 141],
#         [195, 225, 232],
#         [ 93,  30,   0],
#         [  4,  75, 163]],
#
#        [[ 95, 176,  27],
#         [ 16, 196,  50],
#         [142,  45,  25],
#         [  6, 174, 205]]], dtype=int32)

# %%
arr_3_part = np.split(a,3, axis = 2)

# %%
plt.imshow(a)

# %%
len(arr_3_part)
# Out:
# 3

# %%
plt.imshow(arr_3_part[0])

# %%
arr.shape
# Out:
# (783, 1000, 3)

# %%
plt.imshow(np.split(arr,3,axis = 2)[2])

# %%
plt.imshow(np.split(arr,3,axis = 0)[2])

# %%
plt.imshow(np.split(arr,2,axis = 1)[1])

# %%
arr.shape
# Out:
# (783, 1000, 3)

# %%
1000//3
# Out:
# 333

# %%
plt.imshow(arr[:,:333,:])

# %%
plt.imshow(arr[:,:333:333*2,:])

# %%
plt.imshow(arr[:,:333*2,:])

# %%
#where , clip, broadcasting

# %%
a= np.random.randint(1,50,(4,4))
a
# Out:
# array([[ 4, 46,  2, 41],
#        [24, 25, 21, 38],
#        [24, 46, 42, 42],
#        [16, 40, 11, 38]], dtype=int32)

# %%
np.where(a>25)  # comdition
# Out:
# (array([0, 0, 1, 2, 2, 2, 3, 3]), array([1, 3, 3, 1, 2, 3, 1, 3]))

# %%
np.where(a>25,'high sales','lower sales')
# Out:
# array([['lower sales', 'high sales', 'lower sales', 'high sales'],
#        ['lower sales', 'lower sales', 'lower sales', 'high sales'],
#        ['lower sales', 'high sales', 'high sales', 'high sales'],
#        ['lower sales', 'high sales', 'lower sales', 'high sales']],
#       dtype='<U11')

# %%
np.where(a>25,'high sales',a)
# Out:
# array([['4', 'high sales', '2', 'high sales'],
#        ['24', '25', '21', 'high sales'],
#        ['24', 'high sales', 'high sales', 'high sales'],
#        ['16', 'high sales', '11', 'high sales']], dtype='<U11')

# %%
a
# Out:
# array([[ 4, 46,  2, 41],
#        [24, 25, 21, 38],
#        [24, 46, 42, 42],
#        [16, 40, 11, 38]], dtype=int32)

# %%
np.clip(a,30,40) # outliers remove / replace
# Out:
# array([[30, 40, 30, 40],
#        [30, 30, 30, 38],
#        [30, 40, 40, 40],
#        [30, 40, 30, 38]], dtype=int32)

# %%
#broadcasting ( shape,dimensions)

# %%
a = np.random.randint(1,10,7)
b = np.random.randint(1,10,(2,7))
print(a)
print('.....\n\n')
print(b)
# Out:
# [1 4 2 9 7 7 6]
# .....
#
#
# [[8 9 1 4 1 2 5]
#  [3 7 3 5 8 6 4]]

# %%
a+b
# Out:
# array([[ 9, 13,  3, 13,  8,  9, 11],
#        [ 4, 11,  5, 14, 15, 13, 10]], dtype=int32)

# %%
a = np.random.randint(1,10,(7,1))
b = np.random.randint(1,10,(1,7))
print(a)
print('.....\n\n')
print(b)
# Out:
# [[4]
#  [8]
#  [4]
#  [1]
#  [3]
#  [9]
#  [8]]
# .....
#
#
# [[8 7 2 5 8 3 4]]

# %%
a+b
# Out:
# array([[12, 11,  6,  9, 12,  7,  8],
#        [16, 15, 10, 13, 16, 11, 12],
#        [12, 11,  6,  9, 12,  7,  8],
#        [ 9,  8,  3,  6,  9,  4,  5],
#        [11, 10,  5,  8, 11,  6,  7],
#        [17, 16, 11, 14, 17, 12, 13],
#        [16, 15, 10, 13, 16, 11, 12]], dtype=int32)

# %%
# introduction to pandas

# %%
#data = explore (exploratory data analysis) EDA 
#pandas = panel 
# series , data frame

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.3'

# %%
import random 

products =['chair','tables','laptop','mobile phones','charger']
region=['east','west','north','south']
all_date = pd.date_range('01-01-2025','23-07-2025')


data = {'order-id':range(1,1001),
        'date':random.choices(all_date,k=1000),
       'Region Name':random.choices(region,k=1000),
       'product Name':random.choices(products,k=1000),
       'sales':np.random.randint(100,10000,1000),
        'quantity':np.random.randint(1,10,1000),
        'profit':np.random.randint(-10000,10000,1000)}

table = pd.DataFrame(data)
table
# Out:
#      order-id       date Region Name   product Name  sales  quantity  profit
# 0           1 2025-07-16        west         tables   4547         7   -5251
# 1           2 2025-03-31       north          chair   3694         3    7381
# 2           3 2025-03-20       south        charger   3165         4   -6557
# 3           4 2025-05-10        east         tables   1724         7   -5517
# 4           5 2025-01-24       south          chair    315         8   -6427
# ..        ...        ...         ...            ...    ...       ...     ...
# 995       996 2025-01-25        west         laptop   2846         9    2515
# 996       997 2025-03-10        east  mobile phones   8742         4       5
# 997       998 2025-01-06       north         tables   7438         4    7325
# 998       999 2025-03-31       north          chair   8625         7   -6583
# 999      1000 2025-03-27        west         laptop   4308         7    3107
#
# [1000 rows x 7 columns]

# %%
#date column

# %%
all_date = pd.date_range('01-01-2025','23-07-2025')

# %%
#top (by deafult 5)
table.head(10)
# Out:
#    order-id       date Region Name   product Name  sales  quantity  profit
# 0         1 2025-07-16        west         tables   4547         7   -5251
# 1         2 2025-03-31       north          chair   3694         3    7381
# 2         3 2025-03-20       south        charger   3165         4   -6557
# 3         4 2025-05-10        east         tables   1724         7   -5517
# 4         5 2025-01-24       south          chair    315         8   -6427
# 5         6 2025-02-11        west  mobile phones   1331         9    4461
# 6         7 2025-01-03       north         laptop   9644         6    6216
# 7         8 2025-04-19        east        charger   7536         1   -3271
# 8         9 2025-06-17        east  mobile phones   3397         2    4260
# 9        10 2025-01-29       north         laptop   8430         9    2851

# %%
table.tail(7) #bottom
# Out:
#      order-id       date Region Name   product Name  sales  quantity  profit
# 993       994 2025-02-13        east        charger    567         3   -1890
# 994       995 2025-05-24        west         tables   1872         1   -2822
# 995       996 2025-01-25        west         laptop   2846         9    2515
# 996       997 2025-03-10        east  mobile phones   8742         4       5
# 997       998 2025-01-06       north         tables   7438         4    7325
# 998       999 2025-03-31       north          chair   8625         7   -6583
# 999      1000 2025-03-27        west         laptop   4308         7    3107

# %%
table.sample(5)
# Out:
#      order-id       date Region Name product Name  sales  quantity  profit
# 564       565 2025-01-12        east       laptop   5677         6   -3171
# 168       169 2025-02-01        west      charger   2627         7    7317
# 382       383 2025-04-22       south        chair   9518         6   -1176
# 760       761 2025-07-13       north       tables   3140         7   -6051
# 223       224 2025-02-11        west        chair   8397         3    5892

# %%
#information = about dataset #

# %%
table.info() # method
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order-id      1000 non-null   int64
#  1   date          1000 non-null   datetime64[ns]
#  2   Region Name   1000 non-null   object
#  3   product Name  1000 non-null   object
#  4   sales         1000 non-null   int32
#  5   quantity      1000 non-null   int32
#  6   profit        1000 non-null   int32
# dtypes: datetime64[ns](1), int32(3), int64(1), object(2)
# memory usage: 43.1+ KB

# %%
table.columns
# Out:
# Index(['order-id', 'date', 'Region Name', 'product Name', 'sales', 'quantity',
#        'profit'],
#       dtype='object')

# %%
table.index # attribute
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
#isna(): it will check nan value counts 

table.isna()
# Out:
#      order-id   date  Region Name  product Name  sales  quantity  profit
# 0       False  False        False         False  False     False   False
# 1       False  False        False         False  False     False   False
# 2       False  False        False         False  False     False   False
# 3       False  False        False         False  False     False   False
# 4       False  False        False         False  False     False   False
# ..        ...    ...          ...           ...    ...       ...     ...
# 995     False  False        False         False  False     False   False
# 996     False  False        False         False  False     False   False
# 997     False  False        False         False  False     False   False
# 998     False  False        False         False  False     False   False
# 999     False  False        False         False  False     False   False
#
# [1000 rows x 7 columns]

# %%
table.isna().value_counts()
# Out:
# order-id  date   Region Name  product Name  sales  quantity  profit
# False     False  False        False         False  False     False     1000
# Name: count, dtype: int64

# %%
#isnull
table.isnull().value_counts()
# Out:
# order-id  date   Region Name  product Name  sales  quantity  profit
# False     False  False        False         False  False     False     1000
# Name: count, dtype: int64
